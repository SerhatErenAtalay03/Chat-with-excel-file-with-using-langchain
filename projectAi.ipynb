# %% [markdown]
# <a href="https://colab.research.google.com/github/SerhatErenAtalay03/Chat-with-excel-file-with-using-langchain/blob/main/projectAi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.6/990.6 kB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.0/384.0 kB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 6.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
# !pip install langchain-community
# !pip install unstructured
# !pip install openai
# !pip install tiktoken
# !pip install faiss-cpu
# !pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 17.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 36.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 46.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.0 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders import UnstructuredExcelLoader
from langchain.chains.question_answering import load_qa_chain # ilgili excel dosyası ile ilgili soru-cevap kısımlarını oluşturur
from langchain.chat_models import ChatOpenAI # OpenAi 'ın chatgpt'sini kullanmak için import ettik
from langchain.indexes import VectorstoreIndexCreator # veri indexlemek için
from langchain.chains import RetrievalQA # soru-cevap kısımlarını oluşturmak için
from langchain.embeddings import OpenAIEmbeddings # verileri vektör uzayın dönüştürmek için kullanılır


embeddings=OpenAIEmbeddings(openai_api_key='your_api_key') # bu satırdaki kodun çalışabilmesi için openai üzerinden kendi key'inizi kullanmanız gerekir


excelLoader=UnstructuredExcelLoader('/content/drive/MyDrive/Colab Notebooks/veri.xlsx')
index=VectorstoreIndexCreator(embedding=embeddings)
doc=index.from_loaders([excelYukleyicisi])

# bu satırdaki your_api_key e kendi oluşturduğunuz api key i yazmanız gerekir
chain=RetrievalQA.from_chain_type(llm=ChatOpenAI(temperature=0,model="gpt-4",openai_api_key='your_api_key'),
chain_type="stuff",retriever=doc.vectorstore.as_retriever(), input_key="question")


soru="B hissesinin fiyatı kaçtır?"
cevap=chain({"question":soru})
print(cevap)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain/indexes/vectorstore.py:129: UserWarning: Using InMemoryVectorStore as the default vectorstore.This memory store won't persist data. You should explicitlyspecify a vectorstore when using VectorstoreIndexCreator
#   warnings.warn(
# {'question': 'B hissesinin fiyatı kaçtır?', 'result': "B hissesinin fiyatı 24.3'tür."}
